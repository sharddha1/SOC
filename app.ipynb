# %%
with open("data.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts([raw_text])
input_sequences = []
sequence_lengths = []
for line in raw_text.split('\n'):
    tokenized_sentence = tokenizer.texts_to_sequences([line])[0]
    sequence_lengths.append(len(tokenized_sentence))
    for i in range(1, len(tokenized_sentence)):
        input_sequences.append(tokenized_sentence[:i+1])

max_len = max(sequence_lengths)
total_no_words = len(tokenizer.word_index)+1
# Out:
# 1098

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequence = pad_sequences(input_sequences, maxlen=max_len, padding='pre')
x = padded_input_sequence[:,:-1]
y = padded_input_sequence[:, -1]
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, num_classes = total_no_words)
print(x.shape)
# Out:
# (3666, 230)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
model = Sequential()
model.add(Embedding(total_no_words, 100, input_length = 230))
model.add(LSTM(150))
model.add(Dense(total_no_words, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# %%
model.fit(x, y, epochs=100)
# Out:
# Epoch 1/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.9871 - loss: 0.0469
# Epoch 2/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - accuracy: 0.9841 - loss: 0.0511
# Epoch 3/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 12s 105ms/step - accuracy: 0.9853 - loss: 0.0473
# Epoch 4/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 12s 105ms/step - accuracy: 0.9865 - loss: 0.0445
# Epoch 5/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - accuracy: 0.9833 - loss: 0.0538
# Epoch 6/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - accuracy: 0.9868 - loss: 0.0434
# Epoch 7/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.9846 - loss: 0.0450
# Epoch 8/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.9878 - loss: 0.0382
# Epoch 9/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.9881 - loss: 0.0400
# Epoch 10/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.9896 - loss: 0.0390
# Epoch 11/100
# ...

# %%
import time
import numpy as np
text = "A slight shade of"
for i in range(5):
    token_text = tokenizer.texts_to_sequences([text])[0]
    padded_token_text = pad_sequences([token_text], maxlen=max_len, padding="pre")
    pos = np.argmax(model.predict(padded_token_text))
    for word, index in tokenizer.word_index.items():
        if index==pos:
            text = text+" "+word
            print(text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# A slight shade of constraint
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# A slight shade of constraint crossed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# A slight shade of constraint crossed mrs
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# A slight shade of constraint crossed mrs gisburn's
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# A slight shade of constraint crossed mrs gisburn's open
